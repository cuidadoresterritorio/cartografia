# %% [markdown]
# # BioGeografia

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('BIOGEOGRAFIA.csv')
df.head()
# Out:
#    ID    NAME  LASTNAME  EDAD      SECTOR GENERO  AÑOS VIVIENDO  HOJA  \
# 0   1  LEYDY       RUIZ  34.0  CAPELLANIA      F           13.0   1.0
# 1   2    LIA   CEBALLOS  30.0  CAPELLANIA      F           30.0   1.0
# 2   3   OLGA     MORENO  56.0  CAPELLANIA      F           56.0   1.0
# 3   4  ANA F.    ROMERO  72.0  CAPELLANIA      F           13.0   1.0
# 4   5  VICTOR    MORATO  75.0  CAPELLANIA      M           13.0   1.0
#
#        TALLER                            QUE TE MOTIVA ESTAR ACA
# 0  CAPELLANIA  Tranquilidad, naturaleza. Se ha perdido sentid...
# 1  CAPELLANIA                                                NaN
# 2  CAPELLANIA                                                NaN
# 3  CAPELLANIA  Poder subir a la cumbre sin que tengamos que c...
# 4  CAPELLANIA  Implementar una política medioambiental, que l...

# %%
sns.displot(data=df, x='AÑOS VIVIENDO', hue='GENERO')

# %%
sns.displot(data=df, x='EDAD', hue='GENERO', multiple='dodge')

# %% [markdown]
# # hola

# %%
sns.countplot(data=df, y='TALLER', hue='GENERO');

# %%
sns.stripplot(data=df, x='TALLER', y='EDAD', hue='GENERO', dodge=True);

# %%
sns.boxplot(data=df, x='TALLER', y='EDAD', hue='GENERO', dodge='True');

# %%
df = pd.read_csv('BIOGEOGRAFIA.csv')
df.head()
# Out:
#    ID    NAME  LASTNAME  EDAD      SECTOR GENERO  AÑOS VIVIENDO  HOJA  \
# 0   1  LEYDY       RUIZ  34.0  CAPELLANIA      F           13.0     1
# 1   2    LIA   CEBALLOS  30.0  CAPELLANIA      F           30.0     1
# 2   3   OLGA     MORENO  56.0  CAPELLANIA      F           56.0     1
# 3   4  ANA F.    ROMERO  72.0  CAPELLANIA      F           13.0     1
# 4   5  VICTOR    MORATO  75.0  CAPELLANIA      M           13.0     1
#
#        TALLER                            QUE TE MOTIVA ESTAR ACA
# 0  CAPELLANIA  Tranquilidad, naturaleza. Se ha perdido sentid...
# 1  CAPELLANIA                                                NaN
# 2  CAPELLANIA                                                NaN
# 3  CAPELLANIA  Poder subir a la cumbre sin que tengamos que c...
# 4  CAPELLANIA  Implementar una política medioambiental, que l...

# %%
df['VIVIENDO'] = (df['AÑOS VIVIENDO'] / df['EDAD'])*100

# %%
df.head()
# Out:
#    ID    NAME  LASTNAME  EDAD      SECTOR GENERO  AÑOS VIVIENDO  HOJA  \
# 0   1  LEYDY       RUIZ  34.0  CAPELLANIA      F           13.0     1
# 1   2    LIA   CEBALLOS  30.0  CAPELLANIA      F           30.0     1
# 2   3   OLGA     MORENO  56.0  CAPELLANIA      F           56.0     1
# 3   4  ANA F.    ROMERO  72.0  CAPELLANIA      F           13.0     1
# 4   5  VICTOR    MORATO  75.0  CAPELLANIA      M           13.0     1
#
#        TALLER                            QUE TE MOTIVA ESTAR ACA    VIVIENDO
# 0  CAPELLANIA  Tranquilidad, naturaleza. Se ha perdido sentid...   38.235294
# 1  CAPELLANIA                                                NaN  100.000000
# 2  CAPELLANIA                                                NaN  100.000000
# 3  CAPELLANIA  Poder subir a la cumbre sin que tengamos que c...   18.055556
# 4  CAPELLANIA  Implementar una política medioambiental, que l...   17.333333

# %%
sns.displot(data=df, x='VIVIENDO', bins=15)

# %%
sns.boxplot(data=df, x='TALLER', y='VIVIENDO', hue='GENERO', dodge='True')
# Out:
# <Axes: xlabel='TALLER', ylabel='VIVIENDO'>
